# %%
"""Main entry point of application."""

import json

import youtube_api_v3 as yt
from settings import API_KEY

channel_ids = ["UCtJNlrOPYE25Th5ATbgpoow"]

channel_id = channel_ids[0]

youtube = yt.YouTube(channel_id, API_KEY)
response = youtube.get_channel_data()

output_json = json.loads(response.text)

# %%
output_json.keys()

# %%
output_json['items'][0]

# %%
output_json['items'][0].keys()

# %%
output_json['items'][0]['snippet']['title']

# %%
file_name = output_json['items'][0]['snippet']['title'].replace(' ', '_').lower()

# %%
file_name

# %% [markdown]
# ## Extracting data from json saved files.

# %%
import json

# %%
with open('extracts/gaming_shar.json', 'r', encoding='utf-8') as f:
    extract = json.loads(f.read())

# %%
tags = ['snippet', 'contentDetails', 'statistics', 'topicDetails', 'brandingSettings']
for tag in tags:
    data = extract['items'][0][tag]
    print(data.keys())

# %%
data = extract['items'][0]['brandingSettings']
print(data['channel'].keys())
'title', 'description', 'keywords', 'unsubscribedTrailer', 'country'

# %% [markdown]
# ## Get Channel ID from Custom URLs

# %%
from extracts.subscription import channel
from settings import API_KEY

# %%
import requests

# %%
len(channel)
# Out:
# 646

# %%
import json

# %%
with open('temp.txt', 'a', encoding='utf-8') as f:
    for ch in channel:
        if '/user/' in ch:
            custom_name = ch.split('/')[-1]
            response = requests.get(f'https://youtube.googleapis.com/youtube/v3/search?q={custom_name}&key={API_KEY}')
            extract = json.loads(response.text)
            try:
                item = extract['items'][0]['id']
                if item['kind'] == 'youtube#channel':
                    print(custom_name, '+++ All Good!')
                    f.write(item['channelId'])
                    f.write('\n')
            except KeyError:
                print(custom_name, '<<< Error')
                break
# Out:
# ChromeDevelopers +++ All Good!
# GoogleDevelopers +++ All Good!
# gottalentglobal +++ All Good!
# gsmarena07 +++ All Good!
# GuinnessWorldRecords +++ All Good!
# Hak5Darren +++ All Good!
# HardwareCanucks +++ All Good!
# hiteshitube +++ All Good!
# HouseImprovements +++ All Good!
# howtomen +++ All Good!
# iliketomakestuffcom +++ All Good!
# IGNentertainment +++ All Good!
# ItsJuggHere +++ All Good!
# Jayztwocents +++ All Good!
# DrawWithJazza +++ All Good!
# JesseAtomic +++ All Good!
# jiejenn +++ All Good!
# JLaservideo +++ All Good!
# JoeGlines +++ All Good!
# RootOfTheNull +++ All Good!
# NTFAQGuy +++ All Good!
# Ww613wW +++ All Good!
# h28375 +++ All Good!
# KADOKAWAanime +++ All Good!
# kevinparry +++ All Good!
# KepowOb +++ All Good!
# KingOfLighting +++ All Good!
# laowhy86 +++ All Good!
# yesjapan +++ All Good!
# learncodeacademy +++ All Good!
# LearnitTraining +++ All Good!
# LearnWebCode +++ All Good!
# LeeandLie +++ All Good!
# LearnEngineeringTeam +++ All Good!
# rodyinjapan +++ All Good!
# LinusTechTips +++ All Good!
# LironSegev +++ All Good!
# LovesData +++ All Good!
# MagicofRahat +++ All Good!
# onemeeeliondollars +++ All Good!
# marquesbrownlee +++ All Good!
# TheMatteReal +++ All Good!
# mcremona +++ All Good!
# mxmantv +++ All Good!
# MindYourDecisions +++ All Good!
# MKIceAndFire +++ All Good!
# mobiscrub +++ All Good!
# MrBeast6000 +++ All Good!
# nigelscomedythings +++ All Good!
# mgrandpa8 +++ All Good!
# Mhproductionhouse +++ All Good!
# NatGeoWild +++ All Good!
# NaturalWorldFacts +++ All Good!
# NerdorDie +++ All Good!
# NetworkChuck +++ All Good!
# TheRedNile +++ All Good!
# thecodeplanet +++ All Good!
# 1OneSkill +++ All Good!
# PhlearnLLC +++ All Good!
# photoshoptrainingch +++ All Good!
# photoshopCAFE +++ All Good!
# physicswoman +++ All Good!
# PlayStation +++ All Good!
# 00xYumex00 +++ All Good!
# lotsalote +++ All Good!
# BrothersGreenEats +++ All Good!
# programmingwithmosh +++ All Good!
# TelerikInc +++ All Good!
# PurpleRodri +++ All Good!
# redtedart +++ All Good!
# rekjavicxxx +++ All Good!
# theDIYSRC <<< Error

# %%
response

# %%
item = extract['items'][0]['id']
if item['kind'] == 'youtube#channel':
    item['channelId']
