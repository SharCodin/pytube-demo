# %%
"""Main entry point of application."""

import json

import youtube_api_v3 as yt
from settings import API_KEY

channel_ids = ["UCtJNlrOPYE25Th5ATbgpoow"]

channel_id = channel_ids[0]

youtube = yt.YouTube(channel_id, API_KEY)
response = youtube.get_channel_data()

output_json = json.loads(response.text)

# %%
output_json.keys()

# %%
output_json['items'][0]

# %%
output_json['items'][0].keys()

# %%
output_json['items'][0]['snippet']['title']

# %%
file_name = output_json['items'][0]['snippet']['title'].replace(' ', '_').lower()

# %%
file_name

# %% [markdown]
# ## Extracting data from json saved files.

# %%
import json

# %%
with open('extracts/gaming_shar.json', 'r', encoding='utf-8') as f:
    extract = json.loads(f.read())

# %%
tags = ['snippet', 'contentDetails', 'statistics', 'topicDetails', 'brandingSettings']
for tag in tags:
    data = extract['items'][0][tag]
    print(data.keys())

# %%
data = extract['items'][0]['brandingSettings']
print(data['channel'].keys())
'title', 'description', 'keywords', 'unsubscribedTrailer', 'country'

# %% [markdown]
# ## Get Channel ID from Custom URLs

# %%
from extracts.subscription import channel
from settings import API_KEY

# %%
import requests

# %%
len(channel)
# Out:
# 547

# %%
import json

# %%
with open('temp.txt', 'a', encoding='utf-8') as f:
    for ch in channel:
        if '/user/' in ch:
            custom_name = ch.split('/')[-1]
            response = requests.get(f'https://youtube.googleapis.com/youtube/v3/search?q={custom_name}&key=AIzaSyDUHUulj-R5OVWeYg3OBy8IYnWRVLzYLnA')
            extract = json.loads(response.text)
            try:
                item = extract['items'][0]['id']
                if item['kind'] == 'youtube#channel':
                    print(custom_name, '+++ All Good!')
                    f.write(item['channelId'])
                    f.write('\n')
            except KeyError:
                print(custom_name, '<<< Error')
                break
# Out:
# VineMontanaTV +++ All Good!
# scamschool +++ All Good!
# shanselman +++ All Good!
# sentdex +++ All Good!
# SesOHQ +++ All Good!
# 95shawshankk19 +++ All Good!
# fmfunknown +++ All Good!
# SocraticaStudios +++ All Good!
# RSOURAV100 +++ All Good!
# seowhistleblower +++ All Good!
# stevinmarin +++ All Good!
# thestevewallis +++ All Good!
# SurfacedStudio +++ All Good!
# TechDoctorUK +++ All Good!
# TEDtalksDirector +++ All Good!
# TrueGamerSam +++ All Good!
# TheAn1meMan +++ All Good!
# TimBuchalka +++ All Good!
# ThePCSecurity +++ All Good!
# TheJapanChannelDcom +++ All Good!
# TheKiwiGrower +++ All Good!
# theRadBrad +++ All Good!
# TheRelaxingEnd +++ All Good!
# THiNKmediaTV +++ All Good!
# ThioJoe +++ All Good!
# thisoldhouse +++ All Good!
# TigerSpreadsheets +++ All Good!
# EatTim +++ All Good!
# tomstanton282 +++ All Good!
# TechGuyWeb +++ All Good!
# tutor4u +++ All Good!
# tutvid +++ All Good!
# keeroyz +++ All Good!
# undercoverdudes +++ All Good!
# Unity3D +++ All Good!
# ...

# %%
response

# %%
item = extract['items'][0]['id']
if item['kind'] == 'youtube#channel':
    item['channelId']

# %%
import re

# %%
re.sub(r"\W", "_", 'hello wor | this   lskdf .. s- * slkf ')
# Out:
# 'hello_wor___this___lskdf____s____slkf_'
